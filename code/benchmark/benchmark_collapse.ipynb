# %%
import os
import numpy as np
import pandas as pd
from scipy.spatial import cKDTree

# %%
# Read MERSCOPE WT transcripts``
dataset = "Xenium_5K"   # or "MERSCOPE_WT_1/processed_data"
transcripts = pd.read_parquet(f"../../data/{dataset}/transcripts.parquet")
transcripts.head()

# %%
# Spatial resolution
def min_positive_diff(series):
    # unique + sorted values
    vals = np.sort(series.dropna().unique())

    # differences between neighbors
    diffs = np.diff(vals)

    # keep only positive differences
    diffs = diffs[diffs > 0]

    return diffs.min() if len(diffs) else np.nan

x_resolution = min_positive_diff(transcripts["global_x"])
y_resolution = min_positive_diff(transcripts["global_y"])

print("X resolution:", x_resolution)
print("Y resolution:", y_resolution)

# %%
# # Average nearest neighbor distance: Camk2a only
# transcripts = transcripts[transcripts["target"] == "Camk2a"].copy()
# tree = cKDTree(transcripts[["global_x", "global_y"]])
# distances, _ = tree.query(transcripts[["global_x", "global_y"]], k=5)
# nn_distances = distances[:, 1:].mean(axis=1)
# pd.DataFrame({"nn_distances": nn_distances[nn_distances < 25]}).to_parquet("../../output/benchmark/benchmark_collapse.parquet")

# %%
# Average nearest neighbor distance
target_dir = "../../output/Xenium_5K/nearest_neighbors/"
os.makedirs(target_dir, exist_ok=True)

tx = transcripts.loc[transcripts["overlaps_nucleus"] == 0].copy()

gnl_genes = ["Snap25", "Camk2a", "Slc17a7", "Cyfip2", "Map2", "Syp", "Syn1", "Slc32a1", "Vamp2", "Mapt", "Gria2", "Gap43", "Tubb3", "Dlg4", "Gria1", "Bsn"]
selected_genes = ["Snap25", "Camk2a", "Slc17a7"]
ks = [1, 2, 5]

for gene in selected_genes:
    gene_tx = tx.loc[tx["target"] == gene].copy()
    coords = gene_tx[["global_x", "global_y"]].to_numpy()

    # Skip genes with too few points to support the largest k
    if coords.shape[0] < 2:
        continue

    tree = cKDTree(coords)
    out = pd.DataFrame(index=gene_tx.index)

    for k in ks:
        # Need k+1 because the closest match is the point itself (distance 0)
        k_eff = min(k + 1, coords.shape[0])  # guard for small n
        dists, _ = tree.query(coords, k=k_eff)

        # Make dists always 2D for consistent slicing
        if dists.ndim == 1:
            dists = dists[:, None]

        # Drop self (first column), then take the first k real neighbors
        neighbor_dists = dists[:, 1:1 + k]

        # Average across neighbors; for k=1 this is just the single nearest-neighbor distance
        nn_mean = neighbor_dists.mean(axis=1)

        # Apply your <25 filter (keeps NaN for excluded rows, preserving alignment)
        out[f"nn_k{k}"] = np.where(nn_mean < 25, nn_mean, np.nan)

    out.to_parquet(f"{target_dir}/{gene}_nn_mean.parquet")

# %%
# --- Combined (Snap25 + Camk2a + Slc17a7 together) ---
combined_tx = tx.loc[tx["target"].isin(selected_genes)].copy()
combined_coords = combined_tx[["global_x", "global_y"]].to_numpy()

# Skip if too few points
if combined_coords.shape[0] >= 2:
    combined_tree = cKDTree(combined_coords)
    combined_out = pd.DataFrame(index=combined_tx.index)

    for k in ks:
        # Need k+1 because the closest match is the point itself (distance 0)
        k_eff = min(k + 1, combined_coords.shape[0])
        dists, _ = combined_tree.query(combined_coords, k=k_eff)

        # Make dists always 2D for consistent slicing
        if dists.ndim == 1:
            dists = dists[:, None]

        # Drop self (first col), then take first k real neighbors
        neighbor_dists = dists[:, 1:1 + k]

        nn_mean = neighbor_dists.mean(axis=1)

        # Apply the same <25 filter
        combined_out[f"nn_k{k}"] = np.where(nn_mean < 25, nn_mean, np.nan)

    combined_out.to_parquet(f"{target_dir}/selected_genes_combined_nn_mean.parquet")

# %%
# --- Combined (all gnl_genes together) ---
combined_tx = tx.loc[tx["target"].isin(gnl_genes)].copy()
combined_coords = combined_tx[["global_x", "global_y"]].to_numpy()

# Skip if too few points
if combined_coords.shape[0] >= 2:
    combined_tree = cKDTree(combined_coords)
    combined_out = pd.DataFrame(index=combined_tx.index)

    for k in ks:
        # Need k+1 because the closest match is the point itself (distance 0)
        k_eff = min(k + 1, combined_coords.shape[0])
        dists, _ = combined_tree.query(combined_coords, k=k_eff)

        # Make dists always 2D for consistent slicing
        if dists.ndim == 1:
            dists = dists[:, None]

        # Drop self (first col), then take first k real neighbors
        neighbor_dists = dists[:, 1:1 + k]

        nn_mean = neighbor_dists.mean(axis=1)

        # Apply the same <25 filter
        combined_out[f"nn_k{k}"] = np.where(nn_mean < 25, nn_mean, np.nan)

    combined_out.to_parquet(f"{target_dir}/all_gnl_genes_combined_nn_mean.parquet")
